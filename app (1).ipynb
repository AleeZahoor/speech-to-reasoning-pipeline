# %% [markdown]
# <a href="https://colab.research.google.com/github/AleeZahoor/speech-to-reasoning-pipeline/blob/main/app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q openai-whisper
# !pip install -q transformers accelerate bitsandbytes
# !pip install -q soundfile librosa

# %%
import whisper
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
import whisper

whisper_model = whisper.load_model("base")

# %%
audio_file = "your_audio_name.mp3"

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'README.md', 'Recording.m4a', 'app.ipynb', '.ipynb_checkpoints', 'requirements.txt', 'sample_data']

# %%
from google.colab import files
uploaded = files.upload()

audio_file = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-f471164f-9613-4d28-a0be-2d36b1106ba8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f471164f-9613-4d28-a0be-2d36b1106ba8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
result = whisper_model.transcribe(audio_file)

transcription = result["text"]
print("Transcription:", transcription)
# Out:
# Transcription:  What is artificial intelligence? What is the difference between machine learning and deep learning? What is neural networks?

# %%
# !pip install --upgrade transformers bitsandbytes accelerate

# %%
model_name = "unsloth/llama-3-8b-bnb-4bit"  # double check HF repo

# %%
# !pip install -U bitsandbytes transformers accelerate

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import BitsAndBytesConfig
import torch

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,  # memory optimization
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4"
)

# %%
model_name = "meta-llama/Llama-2-7b-chat-hf"

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import torch

# 4-bit config
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4"
)

# ⚠️ USE PUBLIC MODEL (important)
model_name = "facebook/opt-1.3b"  # lightweight & no login needed

# tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto"
)
# Out:
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.decoder.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning

# %%
prompt = f"""
User said:
"{transcription}"

Answer clearly:
"""

inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

outputs = model.generate(
    **inputs,
    max_new_tokens=100
)

response = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(response)
# Out:
# User said:
# " What is artificial intelligence? What is the difference between machine learning and deep learning? What is neural networks?"
#
# Answer clearly:
#
# Machine learning is a type of artificial intelligence that uses machine learning algorithms to learn from data.
#
# Neural networks are a type of artificial neural network that uses neural networks to learn from data.
#
# Machine learning is a type of artificial intelligence that uses machine learning algorithms to learn from data.
#
# Neural networks are a type of artificial neural network that uses neural networks to learn from data.
#
# Machine learning is a type of artificial intelligence that uses machine learning algorithms to learn from data

# %%
result = whisper_model.transcribe(audio_file)

transcription = result["text"]
print("Transcription:", transcription)
# Out:
# Transcription:  What is artificial intelligence? What is the difference between machine learning and deep learning? What is neural networks?

# %%
print(transcription)
# Out:
#  What is artificial intelligence? What is the difference between machine learning and deep learning? What is neural networks?

# %%
inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

outputs = model.generate(
    **inputs,
    max_new_tokens=100,
    temperature=0.7
)

response = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("Final Answer:\n", response)
# Out:
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Final Answer:
#
# User said:
# " What is artificial intelligence? What is the difference between machine learning and deep learning? What is neural networks?"
#
# Answer clearly:
#
# Machine learning is a type of artificial intelligence that uses machine learning algorithms to learn from data.
#
# Neural networks are a type of artificial neural network that uses neural networks to learn from data.
#
# Machine learning is a type of artificial intelligence that uses machine learning algorithms to learn from data.
#
# Neural networks are a type of artificial neural network that uses neural networks to learn from data.
#
# Machine learning is a type of artificial intelligence that uses machine learning algorithms to learn from data
